# %%
import numpy as np

import matplotlib.pyplot as plt
data=np.random.randint(1,100,size=100)
bins=[10,20,30,40,50,60]
plt.hist(data,bins=100,edgecolor="black")
plt.show()

# %%
bins=[10,20,30,40,50,60]
plt.hist(data,bins=bins,edgecolor="black")
plt.axvline(np.random.randint(1,100),linestyle="--",linewidth="2",color="green",label="random no generation")
plt.show()

# %%
arr="shiva"
a=len(arr)
print(a)
arr[0:a:1]
print(arr)
# Out:
# 5
# shiva
