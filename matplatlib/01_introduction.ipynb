# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[4,5,6])

# %%
import numpy as np
num1=1991
num2=[]
for n in range(10):
    num1+=1
    num2.append(num1)
print(num2)
# Out:
# [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001]

# %%
num3=np.arange(2000+1,2000+11)

# %%
print(num3)
# Out:
# [2001 2002 2003 2004 2005 2006 2007 2008 2009 2010]

# %%
plt.plot(num2,num3,c="red")

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]

plt.plot(num2, kohli, label="Virat Kohli")
plt.plot(num2, sehwag, label="Virender Sehwag")

plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.legend()
plt.grid()
plt.show()

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]

plt.plot(num2, kohli)
plt.plot(num2, sehwag)

plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.legend(["kohli","sewag"])#it will used to apply the label
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
for i in range(np.random.randint(1,10)):
    plt.plot(np.random.rand(100),color="red", linewidth=1)

plt.title("Too Much Data Can Be Confusing!")
plt.grid(True)
plt.tight_layout()
plt.show()
