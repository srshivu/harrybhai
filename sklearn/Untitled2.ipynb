# %%
import pandas as pd
d=pd.read_excel(r"C:\Users\shiva\Downloads\Book1.xlsx")
df=pd.DataFrame(d)
df
# Out:
#       sepal length  sepal width   petal length  petal width           class
# 0              5.1          3.5            1.4          0.2     Iris-setosa
# 1              4.9          3.0            1.4          0.2     Iris-setosa
# 2              4.7          3.2            1.3          0.2     Iris-setosa
# 3              4.6          3.1            1.5          0.2     Iris-setosa
# 4              5.0          3.6            1.4          0.2     Iris-setosa
# ..             ...          ...            ...          ...             ...
# 145            6.7          3.0            5.2          2.3  Iris-virginica
# 146            6.3          2.5            5.0          1.9  Iris-virginica
# 147            6.5          3.0            5.2          2.0  Iris-virginica
# 148            6.2          3.4            5.4          2.3  Iris-virginica
# 149            5.9          3.0            5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 x=df["sepal length":"class"]
#       2 print(x)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094 # Do we have a slicer (on rows)?
#    4095 if isinstance(key, slice):
# -> 4096     return self._getitem_slice(key)
#    4098 # Do we have a (boolean) DataFrame?
#    4099 if isinstance(key, DataFrame):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4371, in NDFrame._getitem_slice(self, key)
#    4366 """
#    4367 __getitem__ for the case where the key is a slice object.
#    4368 """
#    4369 # _convert_slice_indexer to determine if this slice is positional
#    4370 #  or label based, and if the latter, convert to positional
# -> 4371 slobj = self.index._convert_slice_indexer(key, kind="getitem")
# ...

# %%
import pandas as pd

data = {
    'Name': ['Ravi', 'Sita', 'Amit', 'John'],
    'Age': [21, 22, 20, 23],
    'Marks': [88, 92, 79, 85]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Name  Age  Marks
# 0  Ravi   21     88
# 1  Sita   22     92
# 2  Amit   20     79
# 3  John   23     85

# %%
df.iloc[1:4,1:3]
# Out:
#    Age  Marks
# 1   22     92
# 2   20     79
# 3   23     85

# %% [markdown]
# ### df.iloc[]

# %%
df.iloc[3,2]=79

# %%
df
# Out:
#    Name  Age  Marks
# 0  Ravi   21     88
# 1  Sita   22     92
# 2  Amit   20     79
# 3  John   23     79

# %%
df["Marks"]=df["Marks"].drop_duplicates()

# %%
df["Marks"]=df["marks"].fillna()
# Out:
#    Name  Age  Marks
# 0  Ravi   21   88.0
# 1  Sita   22   92.0
# 2  Amit   20   79.0
# 3  John   23    NaN
