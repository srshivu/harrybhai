# %%
import numpy as np
arr=np.array([1,2,3,4,5,5,6])
arr
# Out:
# array([1, 2, 3, 4, 5, 5, 6])

# %%
print(np.mean(arr))
# Out:
# 3.7142857142857144

# %%
print(np.sum(arr))
# Out:
# 26

# %%
print(np.min(arr))
# Out:
# 1

# %%
print(np.max(arr))
# Out:
# 6

# %%
print(np.std(arr))
# Out:
# 1.6659862556700857

# %%
print(np.var(arr))
# Out:
# 2.7755102040816326
