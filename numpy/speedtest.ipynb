# %%
import numpy as np

# %%
import time
size=100000
list1=list(range(size))
list2=list(range(size))
start=time.time()
add=[x+y for x,y in zip(list1,list2)]
end=time.time()
print(end-start)
# Out:
# 0.009983539581298828

# %%
import numpy as np
l1=np.arange(1000000)
l2=np.arange(1000000)
start=time.time()
l3=np.add(l1,l2)
end=time.time()
print(end-start)
# Out:
# 0.004960775375366211

# %%
import numpy as np
import time   # import time module

# Example arrays
l1 = np.arange(1000000)   # 1 million numbers
l2 = np.arange(1000000)

start = time.time()
l3 = np.add(l1, l2)       # element-wise addition
end = time.time()

print("Time taken:", end - start, "seconds")
# Out:
# Time taken: 0.0060787200927734375 seconds

# %%
import numpy as np
import time
start=time.time()
lisw=[ x*2 for x in list1]
end=time.time()
print(end-start)
# Out:
# 0.011022090911865234

# %%
arr1=np.arange(100000)
start=time.time()
king=arr1**2
end=time.time()
print(end-start)
# Out:
# 0.0009984970092773438
