# %%
import numpy as np
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
arr=np.array([1,2,3,4,5,6],dtype="float")
arr.reshape(2,3)
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
np.shape(arr)
# Out:
# (6,)

# %% [raw]
# arr.dtype
