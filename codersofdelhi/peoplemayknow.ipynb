# %%
import json
def open_file(file_name):
    with open(file_name,"r") as f:
        return json.load(f)    
def people_you(user_id,data):
    ueser_friends={}
    for user in data['user']:
        user_friends[user["id"]]=set(user["friends"])
    if user_id not in ueser-friends:
        return []
    direct_friends=user_friends[user_id]
    for user in direct_friends:
        for mutual in user_friends[freind]:
            if mutual!=user_id and 
    return data
user_id=1
file_name="data.json"
data=open_file("data.json")
recc=people_you(user_id,data)
print(recc)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 9
#       7 user_id=1
#       8 file_name="data.json"
# ----> 9 data=open_file("data.json")
#      10 recc=people_you(user_id,data)
#      11 print(recc)
#
# Cell In[9], line 4, in open_file(file_name)
#       2 def open_file(file_name):
#       3     with open(file_name,"r") as f:
# ----> 4         return json.load(f)
#
# File ~\anaconda3\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
# ...

# %%
import json

def open_file(file_name):
    with open(file_name, "r") as f:
        return json.load(f)   # ✅ return the data

def people_you(user_id, data):
    return data

user_id = 1
data = open_file("data.json")   # now data will actually hold JSON contents
recc = people_you(user_id, data)
print(recc)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[10], line 11
#       8     return data
#      10 user_id = 1
# ---> 11 data = open_file("data.json")   # now data will actually hold JSON contents
#      12 recc = people_you(user_id, data)
#      13 print(recc)
#
# Cell In[10], line 5, in open_file(file_name)
#       3 def open_file(file_name):
#       4     with open(file_name, "r") as f:
# ----> 5         return json.load(f)
#
# File ~\anaconda3\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
# ...

# %%
data = {
    "users": [
        {"id": 1, "name": "Amit", "friends": [2, 3]},
        {"id": 2, "name": "Priya", "friends": [1, 3]},
        {"id": 3, "name": "Rahul", "friends": [1, 2]}
    ]
}
user_friends={}
for user in data["users"]:
    user_friends[user["id"]]=set(user["friends"])
print(user_friends,"\n")
# Out:
# {1: {2, 3}, 2: {1, 3}, 3: {1, 2}}

# %%
import json
def file_data(file_name):
    with open(file_name,"r") as f:
        return json.load(f)
    
def find_people_you_may(id,data):
    user_friends={}
    for user in data['users']:
        user_friends[user["id"]]=set(user["friends"])
    if id not in user_friends:
        return []
    direct_friends=user_friends[id]
                            
                     
    pass
id=1
data=file_data("data.json")
recc=find_people_you_may(id,data)
print(recc)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 9
#       7     pass
#       8 id=1
# ----> 9 data=file_data("data.json")
#      10 recc=find_people_you_may(id,data)
#      11 print(recc)
#
# Cell In[3], line 4, in file_data(file_name)
#       2 def file_data(file_name):
#       3     with open(file_name,"r") as f:
# ----> 4         return json.load(f)
#
# File ~\anaconda3\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
# ...
