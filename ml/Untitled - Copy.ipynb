# %%
# Out:
# array([30, 50, 70])

# %%
# Out:
# 60

# %%
def shuffle_and_split(data,data_ratio):
    suffle_data=np.random.permutation(len(data))
    print(data[suffle_data])

# %%
shuffle_and_split(data,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 shuffle_and_split(data,4)
#
# NameError: name 'data' is not defined

# %%
indices = np.random.permutation(len(data))
train_size = int(0.5 * len(data))  # 70% for training

train_idx = indices[:train_size]
test_idx = indices[train_size:]
print(train_size)
print("Train indices:", train_idx)
print("Test indices:", test_idx)
# Out:
# 2
# Train indices: [3 0]
# Test indices: [1 2]

# %%
train_test(df,0.8)
# Out:
# (       MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
#  2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
#  3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
#  4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#  5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
#  6      3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
#  ...       ...       ...       ...        ...         ...       ...       ...
#  20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
#  20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
#  20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
#  20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
#  20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#         Longitude
#  2        -122.24
#  3        -122.25
#  4        -122.25
#  5        -122.25
#  6        -122.25
#  ...          ...
#  20635    -121.09
#  20636    -121.21
#  20637    -121.22
#  20638    -121.32
#  20639    -121.24
#
#  [20638 rows x 8 columns],
#     MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
#  0  8.3252      41.0  6.984127    1.02381       322.0  2.555556     37.88
#  1  8.3014      21.0  6.238137    0.97188      2401.0  2.109842     37.86
#
#     Longitude
#  0    -122.23
#  1    -122.22  )

# %%
import pandas as pd
data=pd.read_csv(r"housing.csv")
df=pd.DataFrame(data)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
df["rich_people"]=[ "rich" if i>3.534800 else "poor"for i in df["median_income"]]

# %%
df["total_bedrooms"]=df["total_bedrooms"].fillna(df["total_bedrooms"].mean())

# %%
df.hist(bins=50,figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
import numpy as np
import pandas as pd

def split_and_shuffle(df, test_ratio):
    # Create shuffled indices
    shuffled_indices = np.random.permutation(len(df))
    
    # Calculate test set size
    test_set_size = int(len(df) * test_ratio)
    
    # Split indices for train/test
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    
    # Return split data
    return df.iloc[train_indices], df.iloc[test_indices]

# %%
split_and_shuffle(df,0.8)
# Out:
# (       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#  7261     -118.21     33.99                39.0         47.0            16.0
#  2617     -124.11     40.93                25.0       2392.0           474.0
#  1671     -122.21     38.06                52.0       2735.0           559.0
#  16290    -121.24     37.98                33.0        450.0           123.0
#  2530     -122.20     39.52                39.0       2551.0           482.0
#  ...          ...       ...                 ...          ...             ...
#  5182     -118.25     33.94                37.0       1002.0           270.0
#  3216     -119.65     36.33                52.0       1257.0           257.0
#  3087     -118.87     35.65                33.0       1504.0           325.0
#  6653     -118.14     34.16                38.0       1843.0           565.0
#  10988    -117.80     33.74                30.0       3569.0           551.0
#
#         population  households  median_income  median_house_value  \
#  7261         51.0        23.0         3.2188            112500.0
#  2617       1298.0       461.0         3.5076             73600.0
#  1671       1076.0       487.0         3.6154            155700.0
#  16290       236.0       103.0         1.1964             80400.0
#  2530       1181.0       437.0         2.0625             63400.0
#  ...           ...         ...            ...                 ...
#  5182       1092.0       273.0         1.6333             94500.0
#  3216        624.0       243.0         2.3523             59100.0
#  3087        584.0       223.0         3.4792             94600.0
#  6653       1449.0       524.0         2.2174            215400.0
#  10988      1540.0       537.0         5.2998            247200.0
#
#        ocean_proximity rich_people
#  7261        <1H OCEAN        poor
#  2617       NEAR OCEAN        poor
#  1671         NEAR BAY        rich
#  16290          INLAND        poor
#  2530           INLAND        poor
#  ...               ...         ...
#  5182        <1H OCEAN        poor
#  3216           INLAND        poor
#  3087           INLAND        poor
#  6653        <1H OCEAN        poor
#  10988       <1H OCEAN        rich
#
#  [4128 rows x 11 columns],
#         longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#  8279     -118.15     33.78                13.0       3056.0           861.0
#  6308     -118.01     34.05                37.0        682.0           172.0
#  11791    -121.19     38.87                20.0       3118.0           500.0
#  15832    -122.43     37.75                52.0       2285.0           509.0
#  18463    -121.70     37.20                15.0        531.0           154.0
#  ...          ...       ...                 ...          ...             ...
#  8587     -118.38     33.89                35.0       1778.0           330.0
#  16014    -122.47     37.74                52.0       3688.0           640.0
#  11815    -121.10     38.95                17.0       1475.0           403.0
#  18982    -122.01     38.26                12.0       4132.0           710.0
#  13391    -117.59     34.09                16.0       2401.0           465.0
#
#         population  households  median_income  median_house_value  \
#  8279       1600.0       824.0         3.3003            207800.0
#  6308        813.0       173.0         3.8125            138000.0
#  11791      1405.0       519.0         6.0000            209400.0
#  15832       839.0       456.0         4.7946            355600.0
#  18463       469.0       155.0         4.6500            385700.0
#  ...           ...         ...            ...                 ...
#  8587        732.0       312.0         6.5745            379300.0
#  16014      1605.0       567.0         4.9537            365600.0
#  11815       943.0       363.0         2.1287             55300.0
#  18982      2087.0       633.0         4.5987            139700.0
#  13391      1757.0       500.0         3.9755            120400.0
#
#        ocean_proximity rich_people
#  8279       NEAR OCEAN        poor
#  6308        <1H OCEAN        rich
#  11791          INLAND        rich
#  15832        NEAR BAY        rich
#  18463       <1H OCEAN        rich
#  ...               ...         ...
#  8587        <1H OCEAN        rich
#  16014        NEAR BAY        rich
#  11815          INLAND        poor
#  18982          INLAND        rich
#  13391          INLAND        rich
#
#  [16512 rows x 11 columns])

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   rich_people
# 0        rich
# 1        rich
# 2        rich
# 3        rich
# 4        rich

# %%
df["income_cat"]=pd.cut(df["median_income"],bins=[1,1.5,3,4.5,6,np.inf],labels=[1,2,3,4,5])

# %%
print(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity rich_people income_cat
# 0            NEAR BAY        rich          5
# 1            NEAR BAY        rich          5
# 2            NEAR BAY        rich          5
# 3            NEAR BAY        rich          4
# 4            NEAR BAY        rich          3
# ...               ...         ...        ...
# 20635          INLAND        poor          2
# 20636          INLAND        poor          2
# 20637          INLAND        poor          2
# 20638          INLAND        poor          2
# 20639          INLAND        poor          2
#
# [20640 rows x 12 columns]

# %%
df["income_cat"].value_counts().sort_index().plot.bar(rot=1,grid=True)
# Out:
# <Axes: xlabel='income_cat'>

# %%
df["income_cat"]=df["income_cat"].bfill()

# %%
LIST=[1,2,3,4,5]
print(LIST[:4])
print(list[4:])
# Out:
# [1, 2, 3, 4]
# list[slice(4, None, None)]

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1,test_size=0.3,random_state=42)
for train_index,test_index in split.split(df,df["income_cat"]):
    train_Data=df.iloc[train_index]
    test_data=df.iloc[test_index]

# %%
print(train_Data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20191    -119.22     34.27                11.0       4695.0           955.0
# 15420    -117.26     33.21                26.0       1906.0           408.0
# 12740    -121.35     38.61                25.0       4916.0          1243.0
# 2134     -119.71     36.80                25.0        875.0           156.0
# 5463     -118.47     33.99                33.0        854.0           235.0
# ...          ...       ...                 ...          ...             ...
# 17460    -119.85     34.40                14.0       2307.0           650.0
# 4471     -118.17     34.09                33.0       2907.0           797.0
# 12057    -117.59     33.88                 7.0       3586.0           959.0
# 15021    -117.03     32.79                17.0       7352.0          1699.0
# 14275    -117.13     32.70                42.0       1210.0           292.0
#
#        population  households  median_income  median_house_value  \
# 20191      2065.0       982.0         3.2158            223600.0
# 15420      1325.0       427.0         3.0197            136000.0
# 12740      2140.0      1136.0         2.5511            134100.0
# 2134        646.0       166.0         3.0000             72800.0
# 5463        645.0       198.0         2.1471            239300.0
# ...           ...         ...            ...                 ...
# 17460      5723.0       615.0         2.1652             37500.0
# 4471       3212.0       793.0         2.2348            146600.0
# 12057      2695.0       877.0         2.4387            117000.0
# 15021      3331.0      1634.0         2.7006            166300.0
# 14275       945.0       258.0         0.8991             78900.0
#
#       ocean_proximity rich_people income_cat
# 20191      NEAR OCEAN        poor          3
# 15420       <1H OCEAN        poor          3
# 12740          INLAND        poor          2
# 2134           INLAND        poor          2
# 5463        <1H OCEAN        poor          2
# ...               ...         ...        ...
# 17460      NEAR OCEAN        poor          2
# 4471        <1H OCEAN        poor          2
# 12057          INLAND        poor          2
# 15021       <1H OCEAN        poor          2
# 14275      NEAR OCEAN        poor          1
#
# [14448 rows x 12 columns]

# %% [raw]
# train_data = df.iloc[train_index].drop(columns="income_cat")
# test_data  = df.iloc[test_index].drop(columns="income_cat")

# %%
df["rich_people"].
# Out:
# 0        rich
# 1        rich
# 2        rich
# 3        rich
# 4        rich
#          ...
# 20635    poor
# 20636    poor
# 20637    poor
# 20638    poor
# 20639    poor
# Name: rich_people, Length: 20640, dtype: object

# %%
df["income_cat"].isnull().sum()
# Out:
# 0
