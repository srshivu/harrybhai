# %%
result=(5+3)*13

# %%
result
# Out:
# 104

# %%
re=5+3*13
re
# Out:
# 44

# %%
f=5**2+4**2
f
# Out:
# 41

# %%
#** is the higest precedence in the value it will execute from left to right
# /, // is the lower precedenve then ** it execute from right to left
