# %%
a=5

# %%
b=6

# %%
n=a+b
print(n)
# Out:
# 11

# %%
sr="shiva"

# %%
print(str)
# Out:
# shiva

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(n)
# Out:
# int

# %%
a="33333"

# %%
b="4444"

# %%
a="444"
b="333"
print(a+b)
# Out:
# 444333

# %%
print(float(a)+float(b))#this is a typecasting
# Out:
# 777.0

# %%
n=list("abc")
print(n)
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# string operations

# %%
name="radha rani"
print(name.replace("rani","krisha"))
# Out:
# radha krisha

# %%
name[:1]
# Out:
# 'r'

# %%
name[1:]
# Out:
# 'adha rani'

# %%
name[-1:]
# Out:
# 'i'

# %%
name[-2:]
# Out:
# 'ni'

# %%
name[:-2]
# Out:
# 'radha ra'

# %%
name[-5:-1:1]
# Out:
# ' ran'
