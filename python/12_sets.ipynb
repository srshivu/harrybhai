# %%
se={} #it is not way to create to set 
type(se)
# Out:
# dict

# %% [markdown]
# not sayint the set it will saying dict

# %%
se=set()
type(se)
# Out:
# set

# %%
setti={1,2,3,4,5,6}
setti.add(9)
print(setti)
# Out:
# {1, 2, 3, 4, 5, 6, 9}

# %%
setti.pop()
setti.remove(4)
print(setti)
# Out:
# {3, 5, 6, 9}

# %%
set1={1,2,3,4,5}
set2={1,2,}
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5}

# %% [raw]
# set1.intersection(set2)

# %%
set1&set2#it will equal to intersection
# Out:
# {1, 2}

# %%
l=set1.issubset(set2)
k=set1.issuperset(set2)
print(l)

print(k)
# Out:
# False
# True
