# %%
l=[1,2,3,4,5]
for i in l:
    print(i+1)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(3):
    for j in range(4):
        print(i,j)
# Out:
#   Cell In[7], line 4
#     print(i,j)
#                       ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
l=["shiva","king","huli"]
for i in l:
    if i == "king":
        continue # when matching it will become the true it will skip the code to another liene
    print(i)
# Out:
# shiva
# huli

# %%
l = ["shiva", "king", "huli"]

for i in l:
    if i == "king":   
        break
    print(i)
# Out:
# shiva

# %%
n=2
L=[]
for i in range(1,n):
    for j in range(1,n):
        if i*j==n:
            l.append(n)
print(L)
# Out:
# []

# %%
n=11
for i in range(1,n):
    for j in range(1,n):
        if i*j==n:
            print(n)
