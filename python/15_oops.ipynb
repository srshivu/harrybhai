# %%
class school:
    princi="hugar"
    def printschooldetail(self):
        print(f"the government primary and pre-primary school hm{self.princi}")
s=school()        
s.printschooldetail()
# Out:
# the government primary and pre-primary school hmhugar

# %%
class school:
    princi="hugar"
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
    def printschooldetail(self):
        print(f"the government{self.name} and {self.salary} primary and pre-primary school hm{self.princi}")
s=school("shivu",2222)        
s.printschooldetail()
# Out:
# the governmentshivu and 2222 primary and pre-primary school hmhugar

# %%
class school:
    princi="hugar"
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
    def printschooldetail(self):
        print(f"the government{self.name} and {self.salary} primary and pre-primary school hm{self.princi}")
    @staticmethod
    def notstatic():
      print("it will show error")
s=school("shivu",2222)        
s.printschooldetail() 
s.notstatic()
# Out:
# the governmentshivu and 2222 primary and pre-primary school hmhugar
# it will show error

# %%
class Student:
    school_name = "ABC School"

    def __init__(self, name, age):
        self.name = name
        self.age = age

    # Class method
    @classmethod
    def change_school(cls, new_name):
        cls.school_name = new_name

# Using the class method
print(Student.school_name)   # Output: ABC School

Student.change_school("XYZ School")
print(Student.school_name)   # Output: XYZ School
# Out:
# ABC School
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 17
#      14 # Using the class method
#      15 print(Student.school_name)   # Output: ABC School
# ---> 17 Student.change_school("XYZ School")
#      18 print(Student.school_name)
#
# Cell In[9], line 12, in Student.change_school(cls, new_name)
#       9 @classmethod
#      10 def change_school(cls, new_name):
#      11     cls.school_name = new_name
# ---> 12     print(f"the school name is the {name}")
#
# NameError: name 'name' is not defined
