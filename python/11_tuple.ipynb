# %% [markdown]
# tuple is a order, and immutable but is same to list

# %%
tup=(1,2,3,4)

# %%
tup[2]
# Out:
# 3

# %%
k=min(tup)
km=max(tup)
print(k)
print(km)
# Out:
# 1
# 4

# %%
#packing 
m=("shiba",22,"math")
#unpacking
name,age,sub=m

# %%
name
# Out:
# 'shiba'

# %%
age
# Out:
# 22

# %%
sub
# Out:
# 'math'
