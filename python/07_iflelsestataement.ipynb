# %%
a=400
if (a>41):
    print("grater function")
else :
    print("lesser function")
# Out:
# grater function

# %%
a=int(input("enter the a no"))
b=int(input("enter the b no"))
if a>b:
    print("a is greater")
elif a>=b:
    print(" a is the equal or greater")#once if or elif exicute it will break and it will stop
elif a== b:
    print("a equal b")
else :
    print("b is greater")
# Out:
#   Cell In[6], line 8
#     elif a== b:
#     ^
# SyntaxError: invalid syntax
