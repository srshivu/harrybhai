# %%
# Out:
# [1, 2, 3, 4, 56]

# %%
l=[1,2,3,4,56]
l.append(6)
print(l)
# Out:
# [1, 2, 3, 4, 56, 6]

# %%
l.extend([33])
print(l)
# Out:
# [1, 2, 3, 4, 56, 6, 33]

# %%
l.insert(0,33)
print(l)
# Out:
# [33, 33, 1, 2, 3, 4, 56, 6, 33]

# %%
l.remove(33)#it will remove the first occurence of the element
l
# Out:
# [1, 2, 3, 4, 56, 6, 33]

# %%
l.index(3)
# Out:
# 2

# %%
l.pop(3)
# Out:
# 4

# %%
l
# Out:
# [1, 2, 3, 56, 6, 33]

# %%
k=len(l)
print(k)
# Out:
# 6

# %%
k=sum(l)
print(k)
# Out:
# 101
