# %%
import pandas as pd
data=pd.DataFrame([["shiav",1],["prashan",2],["rajubhai",3]],columns=["name","no"])
data
# Out:
#        name  no
# 0     shiav   1
# 1   prashan   2
# 2  rajubhai   3

# %%
import pandas as pd
import pandas as pd

# Sample dataset
data = [
    {"Name": "Rahul", "Age": 21, "Marks": 85, "City": "Bengaluru"},
    {"Name": "Priya", "Age": 22, "Marks": 90, "City": "Mumbai"},
    {"Name": "Arjun", "Age": 20, "Marks": 75, "City": "Chennai"},
    {"Name": "Sneha", "Age": 23, "Marks": 88, "City": "Delhi"},
    {"Name": "Vikram", "Age": 21, "Marks": 92, "City": "Hyderabad"},
    {"Name": "Kavya", "Age": 19, "Marks": 70, "City": "Pune"},
    {"Name": "Rohan", "Age": 22, "Marks": 95, "City": "Kolkata"},
    {"Name": "Meera", "Age": 20, "Marks": 80, "City": "Jaipur"},
    {"Name": "Anil", "Age": 24, "Marks": 65, "City": "Lucknow"},
    {"Name": "Divya", "Age": 23, "Marks": 89, "City": "Ahmedabad"},
]

# Create DataFrame

df=pd.DataFrame(data)
d=df.to_excel("data1.xlsx",index=False)            
print("sucessufully you added")
# Out:
# sucessufully you added

# %%
rA=df[df["Age"]>=21]
print(rA)
# Out:
#      Name  Age  Marks       City
# 0   Rahul   21     85  Bengaluru
# 1   Priya   22     90     Mumbai
# 3   Sneha   23     88      Delhi
# 4  Vikram   21     92  Hyderabad
# 6   Rohan   22     95    Kolkata
# 8    Anil   24     65    Lucknow
# 9   Divya   23     89  Ahmedabad

# %%
rA.iloc[0:9,2]
# Out:
# 0    85
# 1    90
# 3    88
# 4    92
# 6    95
# 8    65
# 9    89
# Name: Marks, dtype: int64

# %%
import pandas as pd
king=pd.read_excel("data1.xlsx")
print(king)
# Out:
#      Name  Age  Marks       City
# 0   Rahul   21     85  Bengaluru
# 1   Priya   22     90     Mumbai
# 2   Arjun   20     75    Chennai
# 3   Sneha   23     88      Delhi
# 4  Vikram   21     92  Hyderabad
# 5   Kavya   19     70       Pune
# 6   Rohan   22     95    Kolkata
# 7   Meera   20     80     Jaipur
# 8    Anil   24     65    Lucknow
# 9   Divya   23     89  Ahmedabad

# %%
print(df.iloc[9,1])
# Out:
# 23

# %%
print(df.loc[9,"Age"])
# Out:
# 23

# %%
print(df.at[9,"Age"])
# Out:
# 23

# %%
king = pd.read_excel(r"C:\Users\shiva\harrybhai\pandas\data1.xlsx")

# %%
print(df.loc[1:7,"Marks":"City"])
# Out:
#    Marks       City
# 1     90     Mumbai
# 2     75    Chennai
# 3     88      Delhi
# 4     92  Hyderabad
# 5     70       Pune
# 6     95    Kolkata
# 7     80     Jaipur

# %%
# !pip install --upgrade openpyxl

# %%
pip install openpyxl==3.1.5
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
king=pd.read_excel("data1.xlsx")
print(king)
# Out:
#     name  santu  school
# 0  shiva     21     gec
# 1   anil     21  angadi
# 2  santu     21    blde

# %%
import pandas as pd
king=pd.read_excel("data1.xlsx")
print(king)
# Out:
#     name  santu  school
# 0  shiva     21     gec
# 1   anil     21  angadi
# 2  santu     21    blde

# %%
import pandas 
print(pandas.__version__)
# Out:
# 2.3.2

# %%
# !pip install --upgrade numpy pandas

# %%
import numpy as np
import pandas as pd

print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Pandas: 2.3.2
# NumPy: 2.3.2
