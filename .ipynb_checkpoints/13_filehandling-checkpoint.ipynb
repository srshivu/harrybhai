# %%
lis={"name":"shiva","age":25,"marks":43}
lis
# Out:
# {'name': 'shiva', 'age': 25, 'marks': 43}

# %%
lis["adress"]="bengeluru"
lis
# Out:
# {'name': 'shiva', 'age': 25, 'marks': 43, 'adress': 'bengeluru'}

# %%
lis["age"]=92

# %%
lis
# Out:
# {'name': 'shiva', 'marks': 43, 'adress': 'bengeluru', 'age': 92}

# %%
lis["age"]
# Out:
# 92

# %%
lis.get("age")#if agae it is not found it was not able to produce error
# Out:
# 92

# %%
lis.keys()
# Out:
# dict_keys(['name', 'marks', 'adress', 'age'])

# %%
lis.values()
# Out:
# dict_values(['shiva', 43, 'bengeluru', 92])

# %%
lis.items()
# Out:
# dict_items([('name', 'shiva'), ('marks', 43), ('adress', 'bengeluru'), ('age', 92)])

# %%
lis2={"love":"BMW","lov":"7TH"}

# %%
lis.update(lis2)

# %%
lis
# Out:
# {'name': 'shiva',
#  'marks': 43,
#  'adress': 'bengeluru',
#  'age': 92,
#  'love': 'BMW',
#  'lov': '7TH'}

# %%
lis.pop("love")
# Out:
# 'BMW'

# %%
lis.popitem() #it will remove the last elements of the dict
# Out:
# ('lov', '7TH')

# %%
lis
# Out:
# {'name': 'shiva', 'marks': 43, 'adress': 'bengeluru', 'age': 92}

# %%
# Creating a dictionary using comprehension
squares = {x: x**2 for x in range(1, 6)}
print(squares)  # {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
lists={x: x+1 for x in range(2,4)}
print(lists)
# Out:
# {2: 3, 3: 4}

# %%
file=open("shiva.txt","w")
file.write("shiva is the next bellionior")
file.close()

# %%
print(file)
# Out:
# <_io.TextIOWrapper name='shiva.txt' mode='w' encoding='cp1252'>
