# %%
l=[1,2,3,4,5]
for i in l:
    print(i+1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 l=[1,2,3,4,5]
# ----> 2 for i[0] in l:
#       3     print(i+1)
#
# NameError: name 'i' is not defined

# %%
for i in range(3):
    for j in range(4):
        print(i,j)
# Out:
#   Cell In[7], line 4
#     print(i,j)
#                       ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
l=["shiva","king ","huli"]
for i in l:
    if i=="king":
        continue # when matching it will become the true it will skip the code to another liene
    print(i)
# Out:
# shiva
# king
# huli

# %%
l = ["shiva", "king", "huli"]

for i in l:
    if i == "king":   # <-- this part is wrong
        break
    print(i)
# Out:
# shiva
